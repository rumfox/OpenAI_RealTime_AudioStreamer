# %%
import asyncio
import base64
import json
import os
import pyaudio
import shutil
import websockets
from dotenv import load_dotenv

# .env 파일 로드
load_dotenv("openai.env")

class AudioStreamer:
    def __init__(self):
        self.p = pyaudio.PyAudio()

    def mic_audio_in_callback(self, in_data, frame_count, time_info, status):
        payload = base64.b64encode(in_data).decode("utf-8")

        async def send():
            await self.ws.send(
                json.dumps(
                    {
                        "type": "input_audio_buffer.append",
                        "audio": payload,
                    },
                )
            )

        asyncio.run(send())
        return (None, pyaudio.paContinue)

    async def ws_receive_worker(self):
        async for m in self.ws:
            columns, rows = shutil.get_terminal_size()
            maxl = columns - 5
            print(m if len(m) <= maxl else (m[:maxl] + " ..."))
            evt = json.loads(m)
            if evt["type"] == "session.created":
                print("Connected: say something to GPT-4o")
                self.mic_audio_in.start_stream()
            elif evt["type"] == "response.audio.delta":
                audio = base64.b64decode(evt["delta"])
                self.speaker_audio_out.write(audio)

    async def run(self):
        self.mic_audio_in = self.p.open(
            format=pyaudio.paInt16,
            channels=1,
            rate=24000,
            input=True,
            stream_callback=self.mic_audio_in_callback,
            frames_per_buffer=int(24000 / 100) * 2,  # 20ms of audio
            start=False,
        )

        self.speaker_audio_out = self.p.open(
            format=pyaudio.paInt16,
            channels=1,
            rate=24000,
            output=True,
        )

        self.ws = await websockets.connect(
            uri="wss://api.openai.com/v1/realtime?model=gpt-4o-realtime-preview-2024-10-01",
            extra_headers={
                "Authorization": f"Bearer {os.getenv('OPENAI_API_KEY')}",
                "OpenAI-Beta": "realtime=v1",
            },
        )

        asyncio.create_task(self.ws_receive_worker())

        await asyncio.sleep(15 * 60)

# %%
# 원래 코드

# if __name__ == "__main__":
#     asyncio.run(AudioStreamer().run())

# 변경 코드 
if __name__ == "__main__":
    loop = asyncio.get_event_loop()
    if loop.is_running():
        # 이미 실행 중인 이벤트 루프가 있는 경우 (인터랙티브 환경에서 사용)
        loop.create_task(AudioStreamer().run())
    else:
        loop.run_until_complete(AudioStreamer().run())
# Out:
# {"type":"session.created","event_id":"event_AG5KoUffHQA3F2YEhdhRg","session ...
# Connected: say something to GPT-4o
# {"type":"input_audio_buffer.speech_started","event_id":"event_AG5PP8hGw1cgZ ...
# {"type":"input_audio_buffer.speech_stopped","event_id":"event_AG5PQXW3U3itL ...
# {"type":"input_audio_buffer.committed","event_id":"event_AG5PQn8gf19LL1OiFe ...
# {"type":"conversation.item.created","event_id":"event_AG5PQlIQ2bjSBaud8ivqh ...
# {"type":"response.created","event_id":"event_AG5PQFkLCBAqrzeTWRNxs","respon ...
# {"type":"input_audio_buffer.speech_started","event_id":"event_AG5PQm08fu0es ...
# {"type":"response.done","event_id":"event_AG5PQ8CUOSer9ZyfZsnJJ","response" ...
# {"type":"input_audio_buffer.speech_stopped","event_id":"event_AG5PRYqxGbGmU ...
# {"type":"input_audio_buffer.committed","event_id":"event_AG5PRezWFtl3eMIWwe ...
# {"type":"conversation.item.created","event_id":"event_AG5PRdMjMzalWWB67q7Y8 ...
# {"type":"response.created","event_id":"event_AG5PRZIhnnu7rBq3K87Bf","respon ...
# {"type":"response.done","event_id":"event_AG5PRkDc4K6sMsqbWM5kY","response" ...
# {"type":"input_audio_buffer.speech_started","event_id":"event_AG5QFiItPZbZ4 ...
# {"type":"input_audio_buffer.speech_stopped","event_id":"event_AG5QGMHaLRup1 ...
# {"type":"input_audio_buffer.committed","event_id":"event_AG5QGxCXTkFDVfWq9x ...
# {"type":"conversation.item.created","event_id":"event_AG5QGieVRejoimFlb5F6g ...
# {"type":"response.created","event_id":"event_AG5QGVSzNNRnMJRfkgyTa","respon ...
# {"type":"response.output_item.added","event_id":"event_AG5QGoCJ5o0zJOjfDe6s ...
# {"type":"conversation.item.created","event_id":"event_AG5QGacIhECDEk0cFIKZy ...
# {"type":"response.content_part.added","event_id":"event_AG5QGXoVqfXIV7yzMCW ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5QGnmAtbhUqtL ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5QGIwK5G8RYZp ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5QGu4nToZIdvb ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5QG6ZdzLsS40h ...
# {"type":"response.audio.delta","event_id":"event_AG5QGh7gB9aS5CjIsSMpa","re ...
# {"type":"response.audio.delta","event_id":"event_AG5QG5h00hux6MkzFixZa","re ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5QGpjf1mxrpXy ...
# {"type":"response.audio.delta","event_id":"event_AG5QGsEg6Q4CMucp2kdZC","re ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5QGuK8c3wh6IJ ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5QGl2zVZ2VnI0 ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5QGIqPovPsa15 ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5QGIZdjiOo9IS ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5QGNkvXaBnWiq ...
# {"type":"response.audio.delta","event_id":"event_AG5QGEKCn1lc1igaqwWjq","re ...
# {"type":"response.audio.delta","event_id":"event_AG5QGlTk3p4nyx3VNrZw5","re ...
# {"type":"input_audio_buffer.speech_started","event_id":"event_AG5QG2XcdZXvP ...
# {"type":"response.audio.done","event_id":"event_AG5QGbswyAJpMVDKJrmLF","res ...
# {"type":"response.audio_transcript.done","event_id":"event_AG5QGYmadhPVJwjc ...
# {"type":"response.content_part.done","event_id":"event_AG5QGppiW4ScLbhHMElT ...
# {"type":"response.output_item.done","event_id":"event_AG5QG7IZWi8ss4ZK2VyOW ...
# {"type":"response.done","event_id":"event_AG5QGDj8uKA2uZJhwSWqU","response" ...
# {"type":"rate_limits.updated","event_id":"event_AG5QGIDkTgCpFizWhqBoA","rat ...
# {"type":"input_audio_buffer.speech_stopped","event_id":"event_AG5QHibtnjvfv ...
# {"type":"input_audio_buffer.committed","event_id":"event_AG5QH2MRXTVuN0tH6A ...
# {"type":"conversation.item.created","event_id":"event_AG5QHvjZketKx5zGfABhQ ...
# {"type":"response.created","event_id":"event_AG5QHgHVFwyxN1loBuIQy","respon ...
# {"type":"input_audio_buffer.speech_started","event_id":"event_AG5QHQXLdljhw ...
# {"type":"response.done","event_id":"event_AG5QHbdHlYB5n1V4DhVa6","response" ...
# {"type":"input_audio_buffer.speech_stopped","event_id":"event_AG5QI4rsmiAyx ...
# {"type":"input_audio_buffer.committed","event_id":"event_AG5QInPVDP3HdJWsd3 ...
# {"type":"conversation.item.created","event_id":"event_AG5QIP2TCoqm1BBNBIYLR ...
# {"type":"response.created","event_id":"event_AG5QIoTyNK0Lyhjg4zlrS","respon ...
# {"type":"response.output_item.added","event_id":"event_AG5QIJwTzYS1y29Ddme1 ...
# {"type":"conversation.item.created","event_id":"event_AG5QIgQXalf55UdGwqkjb ...
# {"type":"response.content_part.added","event_id":"event_AG5QIFy0pYSvxSSu7Q8 ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5QIkxQTTUSs7e ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5QIpJQI0cPIlT ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5QIITwtQO8g6Z ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5QI4KGJhuP3hC ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5QI60SfK6DW9M ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5QIUhYF1IvQqL ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5QIK3BhIASuIN ...
# {"type":"response.audio.delta","event_id":"event_AG5QInEC3Q4rN9loqWCk7","re ...
# {"type":"response.audio.delta","event_id":"event_AG5QIMq2g53F1hp6v7fGj","re ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5QIAg4IqpIbxF ...
# {"type":"response.audio.delta","event_id":"event_AG5QIE2RJTD1AZQhrii6F","re ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5QIPeUREYNn0A ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5QIYI6Mnkpcr2 ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5QI9GIZ7vPFJU ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5QINPVCd52tn6 ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5QIVQuXFRRJ4x ...
# {"type":"response.audio.delta","event_id":"event_AG5QIQ3pXkbjdi8tKuvQv","re ...
# {"type":"response.audio.delta","event_id":"event_AG5QINVcRKkVi4etxUn3q","re ...
# {"type":"response.audio.delta","event_id":"event_AG5QI07visXMxZNSVPkqx","re ...
# {"type":"response.audio.delta","event_id":"event_AG5QJWBwaWOurKlw2q46u","re ...
# {"type":"input_audio_buffer.speech_started","event_id":"event_AG5QJEwkPV5eI ...
# {"type":"response.audio.done","event_id":"event_AG5QJp1Ms1jE9IHJ598YM","res ...
# {"type":"response.audio_transcript.done","event_id":"event_AG5QJtR0ZkKeEBjx ...
# {"type":"response.content_part.done","event_id":"event_AG5QJ8L0xQdntNEE7xGv ...
# {"type":"response.output_item.done","event_id":"event_AG5QJVpcW7LcBTP9GT37n ...
# {"type":"response.done","event_id":"event_AG5QJfee5znBUPMf9Wjr0","response" ...
# {"type":"rate_limits.updated","event_id":"event_AG5QJTmMDbhMjHDI6gDEk","rat ...
# {"type":"input_audio_buffer.speech_stopped","event_id":"event_AG5QKlvY2IdXM ...
# {"type":"input_audio_buffer.committed","event_id":"event_AG5QKDiYXO3MqOaTBK ...
# {"type":"conversation.item.created","event_id":"event_AG5QKfr5eQ3hLl4ZQ9Gp9 ...
# {"type":"response.created","event_id":"event_AG5QK2wE9RNBBfERS6RXy","respon ...
# {"type":"response.output_item.added","event_id":"event_AG5QLQKDYXDxJ6JoZEmu ...
# {"type":"conversation.item.created","event_id":"event_AG5QL3uSkctRBJSEQJKKX ...
# {"type":"response.content_part.added","event_id":"event_AG5QLyMQOl3NbMjKse5 ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5QL9EeSros5l2 ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5QLkuBPjPrnWN ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5QL3ofASEnrIk ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5QLawKSjqfbDA ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5QLEoR21i1zk0 ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5QLs9bAWHbo5K ...
# {"type":"response.audio.delta","event_id":"event_AG5QLFcaj55u69GwdfBbk","re ...
# {"type":"response.audio.delta","event_id":"event_AG5QLxCbx3HxJWrvQ1Z2j","re ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5QLZmovTTxWaO ...
# {"type":"response.audio.delta","event_id":"event_AG5QL2ft2lywY7BxguVFq","re ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5QLG6PWvig24E ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5QLhDEfmeJ4gB ...
# {"type":"response.audio.delta","event_id":"event_AG5QLOiP5rxPFVKHuqNSC","re ...
# {"type":"response.audio.delta","event_id":"event_AG5QL8EGr1z6VXlNCvMAx","re ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5QLQEMTY7MGep ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5QLzi4M83LXP3 ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5QLIp9mNTHQhV ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5QLREuFPOKLP0 ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5QL7Yl8520tY4 ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5QLbDfrP3ZEGr ...
# {"type":"response.audio.delta","event_id":"event_AG5QLHImJmxQu81XTURi5","re ...
# {"type":"response.audio.delta","event_id":"event_AG5QLHllOcMzPSWnSNcu0","re ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5QLy7vsJlyTWX ...
# {"type":"response.audio.delta","event_id":"event_AG5QLFqto4SBynGpzebYZ","re ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5QL3dkB1q7JqV ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5QLGzTRXURbjE ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5QL7UiEUpYmiq ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5QLw1TvvFfKIf ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5QLrsX3lN7tYj ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5QL7jl6JJ8nS1 ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5QL4znPYPYJY7 ...
# {"type":"response.audio.delta","event_id":"event_AG5QLPgn6UNqOToBpjfYX","re ...
# {"type":"response.audio.delta","event_id":"event_AG5QLlKcd7ocSqmQlKjhf","re ...
# {"type":"response.audio.delta","event_id":"event_AG5QLSmwDYlR5iRZPwgkE","re ...
# {"type":"response.audio.delta","event_id":"event_AG5QLs2iY8ZTjqCowCoAz","re ...
# {"type":"input_audio_buffer.speech_started","event_id":"event_AG5QLQWclswlz ...
# {"type":"response.audio.done","event_id":"event_AG5QLEJw0ds7DL3v3EpNG","res ...
# {"type":"response.audio_transcript.done","event_id":"event_AG5QLevQgqu1a39q ...
# {"type":"response.content_part.done","event_id":"event_AG5QLY6DpaJWL9lxaqbB ...
# {"type":"response.output_item.done","event_id":"event_AG5QLOYm2y2sMbrXptJMc ...
# {"type":"response.done","event_id":"event_AG5QLCUsuWDvETQfZLjpg","response" ...
# {"type":"rate_limits.updated","event_id":"event_AG5QLkb3oPopq5E7QshK6","rat ...
# {"type":"input_audio_buffer.speech_stopped","event_id":"event_AG5QOOALqnCKJ ...
# {"type":"input_audio_buffer.committed","event_id":"event_AG5QO37sBVTnjgcJNl ...
# {"type":"conversation.item.created","event_id":"event_AG5QO6saRHvyjjO3s8V0s ...
# {"type":"response.created","event_id":"event_AG5QOtYuhocuHpi1lQvEn","respon ...
# {"type":"response.done","event_id":"event_AG5QO8AxwKHq2DqE0y6r2","response" ...
# {"type":"rate_limits.updated","event_id":"event_AG5QO16JynjT6DXH1BLWT","rat ...
# {"type":"input_audio_buffer.speech_started","event_id":"event_AG5QPQPRzDN10 ...
# {"type":"input_audio_buffer.speech_stopped","event_id":"event_AG5QQciA2Cc4V ...
# {"type":"input_audio_buffer.committed","event_id":"event_AG5QQOKlgVor3Q8MPU ...
# {"type":"conversation.item.created","event_id":"event_AG5QQfIst5knN4IbcBUtq ...
# {"type":"response.created","event_id":"event_AG5QQZbVfoIxBz0AOkNc7","respon ...
# {"type":"response.done","event_id":"event_AG5QQP2VQQDRplbQQ68YF","response" ...
# {"type":"rate_limits.updated","event_id":"event_AG5QQk7ydZvXm3LEn1k8P","rat ...
# {"type":"input_audio_buffer.speech_started","event_id":"event_AG5QVjbFP715P ...
# {"type":"input_audio_buffer.speech_stopped","event_id":"event_AG5QVHY3JYIRT ...
# {"type":"input_audio_buffer.committed","event_id":"event_AG5QVUJOhcm2Epu4Et ...
# {"type":"conversation.item.created","event_id":"event_AG5QVlPzFFaauxcVrj9YV ...
# {"type":"response.created","event_id":"event_AG5QVlObF6LoTbBZ823mo","respon ...
# {"type":"input_audio_buffer.speech_started","event_id":"event_AG5QWq03ltRYE ...
# {"type":"response.done","event_id":"event_AG5QWMK0ozfON9y8WQBND","response" ...
# {"type":"input_audio_buffer.speech_stopped","event_id":"event_AG5QW0JoK8Rw9 ...
# {"type":"input_audio_buffer.committed","event_id":"event_AG5QW0vbBgcCvBVuSM ...
# {"type":"conversation.item.created","event_id":"event_AG5QWV0bjEPBh4wblLYTt ...
# {"type":"response.created","event_id":"event_AG5QWWT2VD5ecyt1SZzPm","respon ...
# {"type":"response.done","event_id":"event_AG5QWYiOlOLTpyZ2GySLO","response" ...
# {"type":"rate_limits.updated","event_id":"event_AG5QWxyRbbvWCCT3jzOy5","rat ...
# {"type":"input_audio_buffer.speech_started","event_id":"event_AG5QWj0bBGGdC ...
# {"type":"input_audio_buffer.speech_stopped","event_id":"event_AG5QXkcNP9w4B ...
# {"type":"input_audio_buffer.committed","event_id":"event_AG5QXweRS2YC8u5tdq ...
# {"type":"conversation.item.created","event_id":"event_AG5QXHySC9Ume4DzFFYHH ...
# {"type":"response.created","event_id":"event_AG5QXbgO0ExkLuu4CzjFH","respon ...
# {"type":"response.done","event_id":"event_AG5QX6kKWaJAqaT0moAQO","response" ...
# {"type":"rate_limits.updated","event_id":"event_AG5QXjB4omvMzQ7fACQ1C","rat ...
# {"type":"input_audio_buffer.speech_started","event_id":"event_AG5Qi7jR2Qlup ...
# {"type":"input_audio_buffer.speech_stopped","event_id":"event_AG5Qi3yNEn6Tf ...
# {"type":"input_audio_buffer.committed","event_id":"event_AG5QiJEbSFCW8XGweN ...
# {"type":"conversation.item.created","event_id":"event_AG5QiFvydFAkVhhFqdCU2 ...
# {"type":"response.created","event_id":"event_AG5Qin83LJZqj3V2ReAZS","respon ...
# {"type":"response.output_item.added","event_id":"event_AG5QiflpnEPOwc7HOehO ...
# {"type":"conversation.item.created","event_id":"event_AG5QiHPGMfnOwddRnB0i2 ...
# {"type":"response.content_part.added","event_id":"event_AG5Qikf6mUJkHl4psPh ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5Qi2tx7FNFE5j ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5QiLD4jweNjKh ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5QiPRY0vWmond ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5QiNwEmbdy4T2 ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5QiegNR8l28li ...
# {"type":"response.audio.delta","event_id":"event_AG5QiCloldYsZJaPxCqLW","re ...
# {"type":"response.audio.delta","event_id":"event_AG5QiWzPwTvnMdpTAeHri","re ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5Qij8FwsSMU5h ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5QiCmbrletfwI ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5Qi2DiLKEvlM4 ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5QilbY0soCXS0 ...
# {"type":"response.audio.delta","event_id":"event_AG5QjZiqXhmF52X7KAIXr","re ...
# {"type":"response.audio.delta","event_id":"event_AG5QjDw0BCv6Oq0MaoPPk","re ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5QjbwGhPJjTBa ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5QjdMcAOmkW0K ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5Qjs15hNo0BvC ...
# {"type":"response.audio.delta","event_id":"event_AG5QjnsttYHKwZjtWu9GQ","re ...
# {"type":"response.audio.delta","event_id":"event_AG5QjTrbSpQvtmTdLtrpI","re ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5QjbbKlzNZmhY ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5QjbnKCMi986Q ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5QjlxjAY6yB8y ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5QjhWzKbol2PI ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5QjAT5reU2BaS ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5QjNREl7QdyE3 ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5QjjOFFltN3JE ...
# {"type":"response.audio.delta","event_id":"event_AG5QjshfAeAamdclp0f8C","re ...
# {"type":"response.audio.delta","event_id":"event_AG5QjUZQKpdQBHEMn9pgX","re ...
# {"type":"response.audio.delta","event_id":"event_AG5Qj3mr0WnZRY8VpU4ka","re ...
# {"type":"response.audio.delta","event_id":"event_AG5Qj7jScAOmTrCelE9OD","re ...
# {"type":"response.audio.delta","event_id":"event_AG5QjSmQZ1YvGqzdBM0AW","re ...
# {"type":"response.audio.delta","event_id":"event_AG5Qjz350zqFt5V8MIkrW","re ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5QjrQOIqrKIHq ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5QjhjlpA8dbDu ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5QjE5AiMtRSav ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5Qj7fkLP2IBQA ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5QjZ2srT2whL9 ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5QjFIcpygYnXY ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5Qjk2nZGk2wzR ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5QjgmLjwRRyyV ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5QjMGBQbvbMoJ ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5Qj8L7SF1cAZ5 ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5QjZNkvY6HpKd ...
# {"type":"response.audio.delta","event_id":"event_AG5QjvRRfNtQ38wuv6cuA","re ...
# {"type":"response.audio.delta","event_id":"event_AG5QjKGUs9lCcoqdYIp0g","re ...
# {"type":"response.audio.delta","event_id":"event_AG5QjAwbRdR53ymuBuvg5","re ...
# {"type":"response.audio.delta","event_id":"event_AG5Qjv5B2hxCiC4bViaJE","re ...
# {"type":"response.audio.delta","event_id":"event_AG5QjsiCWlW7nypw2n1aU","re ...
# {"type":"response.audio.delta","event_id":"event_AG5QjA9oYkiqCTSKFbfEa","re ...
# {"type":"response.audio.delta","event_id":"event_AG5Qj9MIYWz3SUy0yuo5x","re ...
# {"type":"response.audio.delta","event_id":"event_AG5QjClW4EXHonvP0AUFM","re ...
# {"type":"input_audio_buffer.speech_started","event_id":"event_AG5Qjd0BD3Qvv ...
# {"type":"response.audio.done","event_id":"event_AG5Qj7y855v3ij6yhmqEH","res ...
# {"type":"response.audio_transcript.done","event_id":"event_AG5QjzB7TqsDVH57 ...
# {"type":"response.content_part.done","event_id":"event_AG5QjAmeqhTsZHqEWkYw ...
# {"type":"response.output_item.done","event_id":"event_AG5QjWNFk6eoRw3XsxpZV ...
# {"type":"response.done","event_id":"event_AG5QjHl33sCKBFSK37GPj","response" ...
# {"type":"rate_limits.updated","event_id":"event_AG5Qj3Y2i1OrT4YzWLsbs","rat ...
# {"type":"input_audio_buffer.speech_stopped","event_id":"event_AG5QkFL3CwqpZ ...
# {"type":"input_audio_buffer.committed","event_id":"event_AG5Qkl0aQ9V8EDt4kq ...
# {"type":"conversation.item.created","event_id":"event_AG5QkhYDIxpwgrQWtfZ1T ...
# {"type":"response.created","event_id":"event_AG5QkX1nlQyhb9E4bY5hn","respon ...
# {"type":"response.done","event_id":"event_AG5QkFsmWWvrZlW7m9qoT","response" ...
# {"type":"rate_limits.updated","event_id":"event_AG5Qk4WkXoVlEnmLg9cIz","rat ...
# {"type":"input_audio_buffer.speech_started","event_id":"event_AG5QkQ2qXcvFz ...
# {"type":"input_audio_buffer.speech_stopped","event_id":"event_AG5QpD8PaxhSn ...
# {"type":"input_audio_buffer.committed","event_id":"event_AG5QpQU7dgG2um3Q07 ...
# {"type":"conversation.item.created","event_id":"event_AG5QpXrlK2GOpDNf5qXHE ...
# {"type":"response.created","event_id":"event_AG5QpeIIrZZYRdZl5GavD","respon ...
# {"type":"response.done","event_id":"event_AG5QpsJIlHHDb0DJcykRQ","response" ...
# {"type":"rate_limits.updated","event_id":"event_AG5QpbHifrSk3yWTcc9vv","rat ...
# {"type":"input_audio_buffer.speech_started","event_id":"event_AG5QpGZQNT7kd ...
# {"type":"input_audio_buffer.speech_stopped","event_id":"event_AG5QrkwKl4zLh ...
# {"type":"input_audio_buffer.committed","event_id":"event_AG5QrIDO5x9tPKrpC1 ...
# {"type":"conversation.item.created","event_id":"event_AG5Qr04Ql7tk2Q7YjIKQl ...
# {"type":"response.created","event_id":"event_AG5QrpjqgAqbKueBibyNA","respon ...
# {"type":"response.done","event_id":"event_AG5QsZicRb1jvuA5mQPGL","response" ...
# {"type":"rate_limits.updated","event_id":"event_AG5QsL0jvysoun03dTXz6","rat ...
# {"type":"input_audio_buffer.speech_started","event_id":"event_AG5QssWFWoLxj ...
# {"type":"input_audio_buffer.speech_stopped","event_id":"event_AG5Qspa1ZiUac ...
# {"type":"input_audio_buffer.committed","event_id":"event_AG5QsyL2PTPvNkamPS ...
# {"type":"conversation.item.created","event_id":"event_AG5QsRrYCGvMDbYsY51pK ...
# {"type":"response.created","event_id":"event_AG5QstFDtJjrOHX5DZ19v","respon ...
# {"type":"response.done","event_id":"event_AG5QsGvkatjEcabq9hN9Y","response" ...
# {"type":"rate_limits.updated","event_id":"event_AG5QsTcAmwi5IpEK57unV","rat ...
# {"type":"input_audio_buffer.speech_started","event_id":"event_AG5QtSMNI3lJt ...
# {"type":"input_audio_buffer.speech_stopped","event_id":"event_AG5QuVtHg86Om ...
# {"type":"input_audio_buffer.committed","event_id":"event_AG5Qug37cxRllTVHJ4 ...
# {"type":"conversation.item.created","event_id":"event_AG5QuM8UduOgyk9nGphGu ...
# {"type":"response.created","event_id":"event_AG5Qu2QIcZZp1dv3xXVKc","respon ...
# {"type":"response.done","event_id":"event_AG5QvwPulAzsCmEqgWUtw","response" ...
# {"type":"rate_limits.updated","event_id":"event_AG5QvX03TnbhHuM7LZcYL","rat ...
# {"type":"input_audio_buffer.speech_started","event_id":"event_AG5QvFakIuiWM ...
# {"type":"input_audio_buffer.speech_stopped","event_id":"event_AG5QvOJw6Dyqk ...
# {"type":"input_audio_buffer.committed","event_id":"event_AG5QvzzqtShaYuXeIh ...
# {"type":"conversation.item.created","event_id":"event_AG5QvSVMY1NJ81ljVPISr ...
# {"type":"response.created","event_id":"event_AG5QvJEGPQ13SPyTBCbg1","respon ...
# {"type":"response.done","event_id":"event_AG5QvuC8JpK9kR3JXfp1U","response" ...
# {"type":"rate_limits.updated","event_id":"event_AG5QveLukCzZDpbH1fH8a","rat ...
# {"type":"input_audio_buffer.speech_started","event_id":"event_AG5R7KlMp28el ...
# {"type":"input_audio_buffer.speech_stopped","event_id":"event_AG5R7VCnEVKvq ...
# {"type":"input_audio_buffer.committed","event_id":"event_AG5R70aLy2Qd01jlu7 ...
# {"type":"conversation.item.created","event_id":"event_AG5R776cH1G1PATP5vSWC ...
# {"type":"response.created","event_id":"event_AG5R7yWpB2RGYpsVxsrSk","respon ...
# {"type":"response.output_item.added","event_id":"event_AG5R8NGX60dC4557qx84 ...
# {"type":"conversation.item.created","event_id":"event_AG5R88EVoM8Gbs7TiEjMB ...
# {"type":"response.content_part.added","event_id":"event_AG5R8Hvjc2jlznQZS9H ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5R8Yf6Ysw9kle ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5R8YBIc7aQQZf ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5R8SAt69OWlXr ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5R8DeLbpkzLyH ...
# {"type":"response.audio.delta","event_id":"event_AG5R8WCwOjMWf68E3dp2I","re ...
# {"type":"response.audio.delta","event_id":"event_AG5R8zKBB8ztxF8mpYQyv","re ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5R8PfhXPBGne4 ...
# {"type":"response.audio.delta","event_id":"event_AG5R8VcIzxlZNnOT4CDo1","re ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5R8QxIOu7b252 ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5R8h6ylbjzmUN ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5R8ntNS5tyvrl ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5R8p3WE4m9dg4 ...
# {"type":"response.audio.delta","event_id":"event_AG5R8xnRjWL6XvFhtm5cR","re ...
# {"type":"response.audio.delta","event_id":"event_AG5R8DYEoxviIPEvb4SSH","re ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5R8TOGLHSgfeV ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5R8nBrsuaZlNs ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5R8iXipkgATAg ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5R8XPSbbPzZHJ ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5R8l3WQyS6diJ ...
# {"type":"response.audio.delta","event_id":"event_AG5R8CpojfMf48jJ7hyVJ","re ...
# {"type":"response.audio.delta","event_id":"event_AG5R8aF7hFu9pnwxlpnD8","re ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5R86wkRCahdTk ...
# {"type":"response.audio.delta","event_id":"event_AG5R8jPrLgUOWniNlTd0B","re ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5R8gKD8dlDxWc ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5R8CGvmK5edW1 ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5R8tTyfx77eG2 ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5R8F1fakuwjCj ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5R9LjXIdckW3u ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5R9aD0yXWZhJI ...
# {"type":"response.audio.delta","event_id":"event_AG5R9NmJxIqK4pffhIyWu","re ...
# {"type":"response.audio.delta","event_id":"event_AG5R9IpFiwSo3rgh7Sz59","re ...
# {"type":"response.audio.delta","event_id":"event_AG5R9cq0YR6Bzn3eeBZ2x","re ...
# {"type":"response.audio.delta","event_id":"event_AG5R9bv9CmP6fkDA7HaUe","re ...
# {"type":"response.audio.delta","event_id":"event_AG5R9W5zFLB2ROXiJvGYR","re ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5R9iPB6e0CaIo ...
# {"type":"response.audio.delta","event_id":"event_AG5R9CGFV9MHXNshewUC7","re ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5R9LRhppTdo1Q ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5R9a52v9VrFjN ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5R9rTav8jnCRn ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5R9L9WpsBqJbn ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5R9Jh0biKYxzy ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5R9nlo7sGmd76 ...
# {"type":"response.audio.delta","event_id":"event_AG5R9l6T5MQ2bIPEkaV04","re ...
# {"type":"response.audio.delta","event_id":"event_AG5R9Xj7rRoLpbU8QwiTZ","re ...
# {"type":"input_audio_buffer.speech_started","event_id":"event_AG5R9sp1QmHBo ...
# {"type":"response.audio.done","event_id":"event_AG5R9d3GLFrpmEe1OTiNL","res ...
# {"type":"response.audio_transcript.done","event_id":"event_AG5R9rlZflmo9ucS ...
# {"type":"response.content_part.done","event_id":"event_AG5R9hibTWimrWqGZ5yK ...
# {"type":"response.output_item.done","event_id":"event_AG5R9tymeBJMrOFJzsm7f ...
# {"type":"response.done","event_id":"event_AG5R9xoXRAcKB7330S9eV","response" ...
# {"type":"rate_limits.updated","event_id":"event_AG5R9Pu8Nvf2XpNqV0WRu","rat ...
# {"type":"input_audio_buffer.speech_stopped","event_id":"event_AG5RAMgmYQOXJ ...
# {"type":"input_audio_buffer.committed","event_id":"event_AG5RAdFiNOLwfWe34F ...
# {"type":"conversation.item.created","event_id":"event_AG5RAz9aGsk1xYB5e75L4 ...
# {"type":"response.created","event_id":"event_AG5RAqfSOv9JjMxUW7HEL","respon ...
# {"type":"response.done","event_id":"event_AG5RA4Qm3w4JSMd2U76yy","response" ...
# {"type":"rate_limits.updated","event_id":"event_AG5RAfYFlXpPpweQrJMfT","rat ...
# {"type":"input_audio_buffer.speech_started","event_id":"event_AG5RAh3GSmbde ...
# {"type":"input_audio_buffer.speech_stopped","event_id":"event_AG5RCfczUbfmB ...
# {"type":"input_audio_buffer.committed","event_id":"event_AG5RCPOmNWZkzCoFoO ...
# {"type":"conversation.item.created","event_id":"event_AG5RCy9nv89ZK83WtWrmd ...
# {"type":"response.created","event_id":"event_AG5RCq7IcyPBUBn5HAbbJ","respon ...
# {"type":"response.output_item.added","event_id":"event_AG5RDh0qMAZnpb6bhiMs ...
# {"type":"conversation.item.created","event_id":"event_AG5RDhehPiPyZGVXGUZfx ...
# {"type":"response.content_part.added","event_id":"event_AG5RDR7ccfJjJmqPM4e ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5RD7MK7hKTjfv ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5RDjU8NUzhu6u ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5RDcMkaz3OeEZ ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5RDPWjgkQ5dFY ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5RDWgZBeN8rys ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5RD8GBHCgMmpY ...
# {"type":"response.audio.delta","event_id":"event_AG5RDKjqdOGdXByUIDytn","re ...
# {"type":"response.audio.delta","event_id":"event_AG5RDghdq1XAp6iUIrYju","re ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5RD50Oew2Rdcb ...
# {"type":"response.audio.delta","event_id":"event_AG5RDQeS5v3Wt9C9Bjbwu","re ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5RDaTz4f4tjNL ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5RDBfUwbOsjOn ...
# {"type":"response.audio.delta","event_id":"event_AG5RDLKgAEQz78RoSZvP4","re ...
# {"type":"response.audio.delta","event_id":"event_AG5RDrKs8A2Q1m9piBEsB","re ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5RDsoQ3HJzNeJ ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5RDDWDxHg1L8K ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5RDZShs32tPtx ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5RD9m1qUx1FMt ...
# {"type":"response.audio.delta","event_id":"event_AG5RD30uxxk1HniI7QbT7","re ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5RDQ2lNA0FD9g ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5RDUCDFpVLFfx ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5RDuUomEG9UVz ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5RDfarpULqXlJ ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5RDNlHqhvkvUv ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5RDRlt3FeoHeg ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5RDtxcRe2JrcR ...
# {"type":"response.audio.delta","event_id":"event_AG5RDQIC1zpfu7zR0Fvzt","re ...
# {"type":"response.audio.delta","event_id":"event_AG5RD361JIKbRIQMaQQve","re ...
# {"type":"response.audio.delta","event_id":"event_AG5RDZahkqBRI1DrAhRrc","re ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5RD4s8JJJ5OoD ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5RDyC6yCdUxbx ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5RD3eZtd12zaw ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5RDcCm1FHxc6m ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5RDRYbKH3Eir6 ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5RDO1StxoIYVH ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5RDknOOMJw6P5 ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5RDEUkDtGTbvd ...
# {"type":"response.audio.delta","event_id":"event_AG5RDFQWQzQYygOzbdZkZ","re ...
# {"type":"response.audio.delta","event_id":"event_AG5RDBZYfcKGyaX0Uc6dH","re ...
# {"type":"response.audio.delta","event_id":"event_AG5RDPt0YUdOTHZUvM0Px","re ...
# {"type":"response.audio.delta","event_id":"event_AG5RDRwFIUb1Te0jdU2u9","re ...
# {"type":"response.audio.delta","event_id":"event_AG5RD36mLI1YpjAgAJkso","re ...
# {"type":"response.audio.delta","event_id":"event_AG5RDdY2TXBlFA74qx07p","re ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5REXrPqu01D5X ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5REaWFOzbwdeK ...
# {"type":"response.audio_transcript.delta","event_id":"event_AG5REWLdKO49i3D ...
# {"type":"input_audio_buffer.speech_started","event_id":"event_AG5REraxCMdr4 ...
# {"type":"response.audio.done","event_id":"event_AG5REroQ8rZM9rn2ElOUs","res ...
# {"type":"response.audio_transcript.done","event_id":"event_AG5REcc7Rke4n2uK ...
# {"type":"response.content_part.done","event_id":"event_AG5RESUM2IA4ZR9JhUmX ...
# {"type":"response.output_item.done","event_id":"event_AG5REypAplBwZu3z2hFNg ...
# {"type":"response.done","event_id":"event_AG5REzSsmgKRsJhZjuyGY","response" ...
# {"type":"rate_limits.updated","event_id":"event_AG5REuIeBtelk7dQZ9D7S","rat ...
# {"type":"input_audio_buffer.speech_stopped","event_id":"event_AG5RF3IOnsTf9 ...
# {"type":"input_audio_buffer.committed","event_id":"event_AG5RFYoQlZ0aI7kgC7 ...
# {"type":"conversation.item.created","event_id":"event_AG5RFg6Mf4WVfdvTaKhy1 ...
# {"type":"response.created","event_id":"event_AG5RFVwsq02VzZYit3rPp","respon ...
# {"type":"input_audio_buffer.speech_started","event_id":"event_AG5RFZqmwIulS ...
# {"type":"response.done","event_id":"event_AG5RFsutmdnRuAiCccgQK","response" ...
# {"type":"input_audio_buffer.speech_stopped","event_id":"event_AG5RGYMlfVV0L ...
# {"type":"input_audio_buffer.committed","event_id":"event_AG5RGaKJGE4LgIqvxC ...
# {"type":"conversation.item.created","event_id":"event_AG5RGLLzjMV0hLpxdjgsy ...
# {"type":"response.created","event_id":"event_AG5RGdmfH69nQRqd6oiEf","respon ...
# {"type":"response.done","event_id":"event_AG5RGgy6xB7B0nYUqlJ5B","response" ...
# {"type":"rate_limits.updated","event_id":"event_AG5RGqsoRNKZczZKzbf07","rat ...
# {"type":"input_audio_buffer.speech_started","event_id":"event_AG5RGb07npsHf ...
# {"type":"input_audio_buffer.speech_stopped","event_id":"event_AG5RHLm27gJ64 ...
# {"type":"input_audio_buffer.committed","event_id":"event_AG5RH8UgfM2LS8P4Ra ...
# {"type":"conversation.item.created","event_id":"event_AG5RHLu0eEAVQKPQ57Mg8 ...
# {"type":"response.created","event_id":"event_AG5RHLqnImpI4WlrINLDF","respon ...
# {"type":"response.done","event_id":"event_AG5RHRvZKhOtDDsoG7yz8","response" ...
# {"type":"rate_limits.updated","event_id":"event_AG5RHeOYcKh47TpsGalBY","rat ...
# {"type":"input_audio_buffer.speech_started","event_id":"event_AG5RH31LVzwhR ...
# {"type":"input_audio_buffer.speech_stopped","event_id":"event_AG5RHVdZXVipF ...
# {"type":"input_audio_buffer.committed","event_id":"event_AG5RHqSnCxvHIjtxsV ...
# {"type":"conversation.item.created","event_id":"event_AG5RH2dz0nwKpa5xTK7g0 ...
# {"type":"response.created","event_id":"event_AG5RHI8YRejoU4Vjs8mSZ","respon ...
# {"type":"response.done","event_id":"event_AG5RHNm44CH29vIsWBC2G","response" ...
# {"type":"rate_limits.updated","event_id":"event_AG5RHCgAZzSMHDf92q9iz","rat ...
# Fatal error on SSL protocol
# protocol: <asyncio.sslproto.SSLProtocol object at 0x00000219C82C1340>
# transport: <_SelectorSocketTransport closing fd=2112 read=idle write=<idle, bufsize=0>>
# Traceback (most recent call last):
#   File "c:\Users\rumfox\AppData\Local\Programs\Python\Python312\Lib\asyncio\sslproto.py", line 694, in _write_appdata
#     self._do_write()
#   File "c:\Users\rumfox\AppData\Local\Programs\Python\Python312\Lib\asyncio\sslproto.py", line 709, in _do_write
#     del self._write_backlog[0]
#         ~~~~~~~~~~~~~~~~~~~^^^
# IndexError: deque index out of range
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\rumfox\AppData\Local\Temp\ipykernel_3752\407605252.py", line 30, in mic_audio_in_callback
#     asyncio.run(send())
#   File "c:\Users\rumfox\AppData\Local\Programs\Python\Python312\Lib\asyncio\runners.py", line 194, in run
#     return runner.run(main)
#            ^^^^^^^^^^^^^^^^
#   File "c:\Users\rumfox\AppData\Local\Programs\Python\Python312\Lib\asyncio\runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\rumfox\AppData\Local\Programs\Python\Python312\Lib\asyncio\base_events.py", line 687, in run_until_complete
#     return future.result()
#            ^^^^^^^^^^^^^^^
#   File "C:\Users\rumfox\AppData\Local\Temp\ipykernel_3752\407605252.py", line 21, in send
#     await self.ws.send(
#   File "c:\Users\rumfox\Project\ChatGPT\.venv\Lib\site-packages\websockets\legacy\protocol.py", line 640, in send
#     await self.write_frame(True, opcode, data)
#   File "c:\Users\rumfox\Project\ChatGPT\.venv\Lib\site-packages\websockets\legacy\protocol.py", line 1199, in write_frame
#     await self.drain()
#   File "c:\Users\rumfox\Project\ChatGPT\.venv\Lib\site-packages\websockets\legacy\protocol.py", line 1182, in drain
#     await self._drain()
#   File "c:\Users\rumfox\Project\ChatGPT\.venv\Lib\site-packages\websockets\legacy\protocol.py", line 328, in _drain
#     raise exc
#   File "c:\Users\rumfox\Project\ChatGPT\.venv\Lib\site-packages\websockets\legacy\protocol.py", line 953, in transfer_data
#     message = await self.read_message()
#               ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\rumfox\Project\ChatGPT\.venv\Lib\site-packages\websockets\legacy\protocol.py", line 1023, in read_message
#     frame = await self.read_data_frame(max_size=self.max_size)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\rumfox\Project\ChatGPT\.venv\Lib\site-packages\websockets\legacy\protocol.py", line 1098, in read_data_frame
#     frame = await self.read_frame(max_size)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\rumfox\Project\ChatGPT\.venv\Lib\site-packages\websockets\legacy\protocol.py", line 1155, in read_frame
#     frame = await Frame.read(
#             ^^^^^^^^^^^^^^^^^
#   File "c:\Users\rumfox\Project\ChatGPT\.venv\Lib\site-packages\websockets\legacy\framing.py", line 70, in read
#     data = await reader(2)
#            ^^^^^^^^^^^^^^^
#   File "c:\Users\rumfox\AppData\Local\Programs\Python\Python312\Lib\asyncio\streams.py", line 752, in readexactly
#     await self._wait_for_data('readexactly')
#   File "c:\Users\rumfox\AppData\Local\Programs\Python\Python312\Lib\asyncio\streams.py", line 545, in _wait_for_data
#     await self._waiter
#   File "c:\Users\rumfox\AppData\Local\Programs\Python\Python312\Lib\asyncio\sslproto.py", line 694, in _write_appdata
#     self._do_write()
#   File "c:\Users\rumfox\AppData\Local\Programs\Python\Python312\Lib\asyncio\sslproto.py", line 709, in _do_write
#     del self._write_backlog[0]
#         ~~~~~~~~~~~~~~~~~~~^^^
# IndexError: deque index out of range
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\rumfox\AppData\Local\Programs\Python\Python312\Lib\logging\__init__.py", line 1160, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\rumfox\AppData\Local\Programs\Python\Python312\Lib\logging\__init__.py", line 999, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "c:\Users\rumfox\AppData\Local\Programs\Python\Python312\Lib\logging\__init__.py", line 711, in format
#     record.exc_text = self.formatException(record.exc_info)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\rumfox\AppData\Local\Programs\Python\Python312\Lib\logging\__init__.py", line 661, in formatException
#     traceback.print_exception(ei[0], ei[1], tb, None, sio)
#   File "c:\Users\rumfox\AppData\Local\Programs\Python\Python312\Lib\traceback.py", line 124, in print_exception
#     te = TracebackException(type(value), value, tb, limit=limit, compact=True)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\rumfox\AppData\Local\Programs\Python\Python312\Lib\traceback.py", line 733, in __init__
#     self.stack = StackSummary._extract_from_extended_frame_gen(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\rumfox\AppData\Local\Programs\Python\Python312\Lib\traceback.py", line 438, in _extract_from_extended_frame_gen
#     f.line
#   File "c:\Users\rumfox\AppData\Local\Programs\Python\Python312\Lib\traceback.py", line 323, in line
#     self._line = linecache.getline(self.filename, self.lineno)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\rumfox\AppData\Local\Programs\Python\Python312\Lib\linecache.py", line 30, in getline
#     lines = getlines(filename, module_globals)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\rumfox\AppData\Local\Programs\Python\Python312\Lib\linecache.py", line 46, in getlines
#     return updatecache(filename, module_globals)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\rumfox\AppData\Local\Programs\Python\Python312\Lib\linecache.py", line 93, in updatecache
#     stat = os.stat(fullname)
#            ^^^^^^^^^^^^^^^^^
# IndexError
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\rumfox\Project\ChatGPT\.venv\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\rumfox\Project\ChatGPT\.venv\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\rumfox\Project\ChatGPT\.venv\Lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "c:\Users\rumfox\Project\ChatGPT\.venv\Lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "c:\Users\rumfox\AppData\Local\Programs\Python\Python312\Lib\asyncio\base_events.py", line 641, in run_forever
#     self._run_once()
#   File "c:\Users\rumfox\AppData\Local\Programs\Python\Python312\Lib\asyncio\base_events.py", line 1986, in _run_once
#     handle._run()
#   File "c:\Users\rumfox\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\rumfox\Project\ChatGPT\.venv\Lib\site-packages\websockets\legacy\protocol.py", line 1009, in transfer_data
#     self.logger.error("data transfer failed", exc_info=True)
# Message: 'data transfer failed'
# Arguments: ()
